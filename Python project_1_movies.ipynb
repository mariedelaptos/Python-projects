# %%
# Import libraries:

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
import IPython
print(IPython.sys_info())
# Out:
# {'commit_hash': '3813660de',
#  'commit_source': 'installation',
#  'default_encoding': 'cp1252',
#  'ipython_path': 'C:\\Users\\HP EliteBook 820 '
#                  'G3\\anaconda3\\Lib\\site-packages\\IPython',
#  'ipython_version': '7.29.0',
#  'os_name': 'nt',
#  'platform': 'Windows-10-10.0.19044-SP0',
#  'sys_executable': 'C:\\Users\\HP EliteBook 820 G3\\anaconda3\\python.exe',
#  'sys_platform': 'win32',
#  'sys_version': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit '
#                 '(AMD64)]'}

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

print(plt.rcParams['figure.figsize'])
plt.rcParams['figure.figsize'] = [12,8]
print(plt.rcParams['figure.figsize'])
# Out:
# [6.0, 4.0]
# [12.0, 8.0]

# %%
# Read the data:

df = pd.read_csv(r'C:\Users\HP EliteBook 820 G3\Desktop\Project 1-4\movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Looking for a missing data:

for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, percent_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Checking the data types of columns:

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
 # Convert nan/null to 0 because without this convertation I got the error in 19 line "IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer"
    
df['budget'] = df['budget'].fillna(0)
df['gross'] = df['gross'].fillna(0)

# %%
# Changing dtype of budget, gross column from float64 to integer:

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# We see that in columns "year" and "released" date values are not maching. And we have the samr with column 'Country'.
# Let's fix it:

# %%
print(df['released'])
# Out:
# 0          June 13, 1980 (United States)
# 1           July 2, 1980 (United States)
# 2          June 20, 1980 (United States)
# 3           July 2, 1980 (United States)
# 4          July 25, 1980 (United States)
#                       ...
# 7663    October 23, 2020 (United States)
# 7664    February 7, 2020 (United States)
# 7665           April 27, 2020 (Cameroon)
# 7666     October 1, 2020 (United States)
# 7667     August 19, 2020 (United States)
# Name: released, Length: 7668, dtype: object

# %%
# Spliting and coverting date to datetype:
from datetime import datetime
pd.to_datetime(df['released'].str.split(r'(').str[0],infer_datetime_format=True)
# Out:
# 0      1980-06-13
# 1      1980-07-02
# 2      1980-06-20
# 3      1980-07-02
# 4      1980-07-25
#           ...
# 7663   2020-10-23
# 7664   2020-02-07
# 7665   2020-04-27
# 7666   2020-10-01
# 7667   2020-08-19
# Name: released, Length: 7668, dtype: datetime64[ns]

# %%
# Adding a new column with separeted year:
df['year_correct'] = pd.to_datetime(df['released'].str.split(r'(').str[0],infer_datetime_format=True).astype(str).str[0:4]#first 4 simbols

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#df['released'].str.split('(').str[0]  - the second way to split

# %%
df['Country_correct'] = df['released'].str.split('(',1).str[1]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Delete the last right perentesis:
df['Country_correct'] = df['Country_correct'].str.translate({ord(')'): None for i in ')'})
df['Country_correct']
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 7663    United States
# 7664    United States
# 7665         Cameroon
# 7666    United States
# 7667    United States
# Name: Country_correct, Length: 7668, dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Done!

# %%
# Order by gross:
df.sort_values(by=['gross'],inplace=False, ascending=False)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# to display max of rows:
#pd.set_option('display.max_rows', None)

# %%
# Dropping duplicates:
df.drop_duplicates()#.sort_values(ascending=False)
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# --------------Let's find the correlation in data.-------------
# What things are most correlative to the gross revenue:

# %%
# Scatter plot with budget and gross:

plt.scatter(x=df['budget'],y=df['gross'])

plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross')
plt.ylabel('Budget')

plt.show()

# %%
# Visually we see strong possitive correlation above. We should aprove it.

# %%
# Use seaborn.

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"green"}, line_kws={"color":"red"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# The budget and the gross are correlated.

# %%
#Determine what the actual correlation is:

df.corr(method='pearson') #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# We see the high correlation.
# Let's see it on a heatmap:

# %%
correlation_matric = df.corr(method='pearson')
sns.heatmap(correlation_matric, annot=True)

plt.title('Correlation Matric')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

plt.show()

# %% [markdown]
# Column 'Company' is not numeric and we can't see correlation without numbers.

# %%
df_num = df
for col_name in df_num.columns:
    if(df_num[col_name].dtype == 'object'):
        df_num[col_name] = df_num[col_name].astype('category')
        df_num[col_name] = df_num[col_name].cat.codes

# %%
df_num.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  year_correct  \
# 0  1047       54  19000000   46998772     2319    146.0             0
# 1   327       55   4500000   58853106      731    104.0             0
# 2  1745       55  18000000  538375067     1540    124.0             0
# 3  2246       55   3500000   83453539     1812     88.0             0
# 4   410       55   6000000   39846344     1777     98.0             0
#
#    Country_correct
# 0               56
# 1               56
# 2               56
# ...

# %%
# to display max of rows:
pd.set_option('display.max_rows', 100)

# %%
correlation_matrix = df_num.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric with all features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

plt.show()

# %%
df_num.corr()
# Out:
#                      name    rating     genre      year  released     score  \
# name             1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating          -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre            0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year             0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released        -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score            0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes            0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director         0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer           0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star             0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country         -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# ...

# %%
#Unstacking

corr_mat = df_num.corr()

corr_pairs = corr_mat.unstack()

corr_pairs
# Out:
# name             name               1.000000
#                  rating            -0.008069
#                  genre              0.016355
#                  year               0.011453
#                  released          -0.011311
#                                       ...
# Country_correct  gross              0.119313
#                  company            0.093962
#                  runtime           -0.012612
#                  year_correct      -0.093351
#                  Country_correct    1.000000
# Length: 289, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre            budget            -0.334021
# budget           genre             -0.334021
# genre            gross             -0.234297
# gross            genre             -0.234297
# genre            votes             -0.145307
#                                       ...
# year             year               1.000000
# genre            genre              1.000000
# rating           rating             1.000000
# year_correct     year_correct       1.000000
# Country_correct  Country_correct    1.000000
# Length: 289, dtype: float64

# %%
# Find high correlation:
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes            gross              0.632834
# gross            votes              0.632834
# budget           gross              0.750157
# gross            budget             0.750157
# year             year_correct       0.997295
# year_correct     year               0.997295
# name             name               1.000000
# writer           writer             1.000000
# runtime          runtime            1.000000
# company          company            1.000000
# gross            gross              1.000000
# budget           budget             1.000000
# country          country            1.000000
# star             star               1.000000
# director         director           1.000000
# votes            votes              1.000000
# score            score              1.000000
# released         released           1.000000
# year             year               1.000000
# genre            genre              1.000000
# rating           rating             1.000000
# ...

# %%
# Budget and votes have the highest correlation and Company has low correlation.
